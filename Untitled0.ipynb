# %% [markdown]
# <a href="https://colab.research.google.com/github/CristianGuerr/Prog_Civil_2026_1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1 Dosificación de Mezcla para Columnas

# %% [markdown]
# #**Dosificación de Mezcla para Columnas**
# **Planteamiento:**
#
# Un ingeniero residente necesita calcular cuántos sacos de cemento se requieren para vaciar una columna de sección circular.
#
# Se sabe que para un concreto estándar de 210 kg/cm2  (3000 psi), se consumen 9.5 sacos de cemento por cada metro cúbico de mezcla.
#
# **Requerimientos:**
#
# 1. Solicitar la altura de la columna en metros.
# 2. Solicitar el diámetro de la columna en metros.
# 3. Calcular el volumen de la columna: $$v =\pi * r^2 * h$$
# . (Sugerencia: usar 3.1416
#  o importar math.pi).
# 4. Calcular la cantidad de sacos:
#
# $$sacos = v * 9.5$$
#
# **Prueba del programa:**
#
# Para una columna de 3 metros de alto y 0.4 metros de diámetro (r=0.2
# ):
#
# Volumen ≈0.377 m3
#
# Sacos necesarios ≈3.58
#
#  (el estudiante verá aquí la importancia de los tipos decimales).

# %% [markdown]
# 1 # ENTRADA:

# %% [markdown]
# 1 #

# %%
# ENTRADA: Solicitar la altura de la columna en metros
# Solicitar el diametro de la columna en metros.
h = float(input("Ingrese la altura de la columna en metros: "))
d = float(input("Ingrese el diámetro de la columna en metros: "))

# PROCESO: Calcula el radio r, calcula el volumen de la columna, calcula sacos
r = d/2
v = 3.1416 * r**2 *h
sacos = v * 9.5

# SALIDA: Imprime el resultado
print("Volumen ≈", round (v, 3), "m3.")
print("Sacos necesarios ≈", round(sacos, 2))
# Out:
# Ingrese la altura de la columna en metros: 3
# Ingrese el diámetro de la columna en metros: 0.4
# Volumen ≈ 0.377 m3.
# Sacos necesarios ≈ 3.58

# %% [markdown]
# ```markdown
# El código en la celda anterior (`0SymVqnKYWkR`) realiza el siguiente proceso:
#
# ```python
# # ENTRADA: Solicitar la altura de la columna en metros
# # Solicitar el diametro de la columna en metros.
# h = float(input("Ingrese la altura de la columna en metros: "))
# d = float(input("Ingrese el diámetro de la columna en metros: "))
# ```
# *   **Líneas 1-2 (`# ENTRADA...`)**: Estos son comentarios que indican que las siguientes líneas se encargan de la entrada de datos.
# *   **Línea 3 (`h = float(input(...))`)**: Solicita al usuario que ingrese la altura de la columna en metros. La función `input()` lee la entrada del usuario como una cadena de texto, y `float()` la convierte a un número decimal (`float`), que se almacena en la variable `h`.
# *   **Línea 4 (`d = float(input(...))`)**: Similar a la anterior, solicita al usuario que ingrese el diámetro de la columna en metros y lo almacena como un número decimal en la variable `d`.
#
# ```python
# # PROCESO: Calcula el radio r, calcula el volumen de la columna, calcula sacos
# r = d/2
# v = 3.1416 * r**2 *h
# sacos = v * 9.5
# ```
# *   **Línea 6 (`# PROCESO...`)**: Comentario que describe el inicio de la sección de procesamiento.
# *   **Línea 7 (`r = d/2`)**: Calcula el radio (`r`) de la columna dividiendo el diámetro (`d`) entre 2.
# *   **Línea 8 (`v = 3.1416 * r**2 *h`)**: Calcula el volumen (`v`) de la columna cilíndrica utilizando la fórmula `π * radio² * altura`. Se usa `3.1416` como una aproximación de Pi.
# *   **Línea 9 (`sacos = v * 9.5`)**: Calcula la cantidad total de sacos de cemento (`sacos`) necesarios multiplicando el volumen de la columna (`v`) por la cantidad de sacos requeridos por metro cúbico (9.5).
#
# ```python
# # SALIDA: Imprime el resultado
# print("Volumen ≈", round (v, 3), "m3.")
# print("Sacos necesarios ≈", round(sacos, 2))
# ```
# *   **Línea 11 (`# SALIDA...`)**: Comentario que indica la sección de salida o presentación de resultados.
# *   **Línea 12 (`print("Volumen ≈"...)`)**: Imprime el volumen calculado. `round(v, 3)` redondea el volumen a tres decimales para una mejor legibilidad.
# *   **Línea 13 (`print("Sacos necesarios"...)`)**: Imprime la cantidad de sacos de cemento necesarios. `round(sacos, 2)` redondea esta cantidad a dos decimales.
# ```
